# %%
# Connexion au répertoire
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Imports

# %%
pip install -q -U keras-tuner
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 5.5 MB/s eta 0:00:00

# %%
# Libraries
import pandas as pd
import numpy as np
import random
import os
from tqdm import tqdm
import itertools
import PIL
import cv2
import keras_tuner as kt

# Data Analysis
import matplotlib.pyplot as plt

#TensorFlow
import tensorflow as tf
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array
from tensorflow import keras

# Sklearn
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# Classes Tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, GlobalAveragePooling2D, Input
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %matplotlib inline

# %% [markdown]
# # Config

# %%
# Chemin d'accès ### A MODIFIER EN LOCAL !!
path = "/content/gdrive/MyDrive/Projet Radio_DS/data/"
ID_DIR = 6

# Accès aux sous-dossiers
dirsi = ["Normal/images/","COVID/images/","Lung_Opacity/images/","Viral Pneumonia/images/"]
dirsim = ["Normal/masked_images/","COVID/masked_images/","Lung_Opacity/masked_images/","Viral Pneumonia/masked_images/"]


# Images à traiter (brutes ou masquées) et taille échantillon
dirs = dirsim
ECH_SIZE = 2000 #(max 2000 sur images masquées par seul un échantillon dispo)

# Classes de 0 à 3 dans la suite
classes = ("Normal","COVID ","Lung_Opacity","Viral Pneumonia")
nbClasses = len(classes)

# Paramètres
SIZE = (240,240)
RATIO_VAL = 0.2
BATCH_SIZE = 32 # Batch pour générateur d'images
MODEL_BATCH_SIZE = 32 # Batch pour entrainement modèle
NB_EPOCHS = 30

# %% [markdown]
# # Création des dataframes

# %%
### Création des listes d'emplacement pour chaque catégorie

liste_paths = [] #Sert à créer le dataframe
liste_test = [] # Sert à conserver toujours les mêmes mages de test (pour tous les modèles)
test_size = int(RATIO_VAL * ECH_SIZE // nbClasses) # Taille de l'échantillon de test à conserver pour chaque catégorie

for class_dir in dirs :
  class_images_names = [fn for fn in os.listdir(path + class_dir) if fn.endswith('.png')]
  for filename in class_images_names[0: (ECH_SIZE // nbClasses)] :
    liste_paths.append(path + class_dir + filename)

  # Récupération d'un échantillon de test
  for i in range(test_size):
    liste_test.append(liste_paths[-test_size:][i])
  liste_paths = liste_paths[:-test_size]

# Récupération de la catégorie de chaque image
liste_paths = list(map(lambda x : [x, x.split('/')[ID_DIR]], liste_paths))
liste_test = list(map(lambda x : [x, x.split('/')[ID_DIR]], liste_test))

# %%
# Création d'un DataFrame Entrainement et de validation
df = pd.DataFrame(liste_paths, columns = ['filepath', 'nameLabel'])
df['label'] = df['nameLabel'].replace(df.nameLabel.unique(), [*range(len(df.nameLabel.unique()))])
df['label'] = df['label'].astype(str)

# Mélange du dataframe
df =  df.sample(frac=1, random_state=42)
df = df.reset_index(drop=True)

# Nettoyage variables inutiles
del liste_paths

print(df["nameLabel"].value_counts())
df.head()
# Out:
# COVID              400
# Normal             400
# Lung_Opacity       400
# Viral Pneumonia    400
# Name: nameLabel, dtype: int64
#                                             filepath     nameLabel label
# 0  /content/gdrive/MyDrive/Projet Radio_DS/data/C...         COVID     1
# 1  /content/gdrive/MyDrive/Projet Radio_DS/data/N...        Normal     0
# 2  /content/gdrive/MyDrive/Projet Radio_DS/data/N...        Normal     0
# 3  /content/gdrive/MyDrive/Projet Radio_DS/data/N...        Normal     0
# 4  /content/gdrive/MyDrive/Projet Radio_DS/data/L...  Lung_Opacity     2

# %%
# Création du DataFrame de test
df_test = pd.DataFrame(liste_test, columns = ['filepath', 'nameLabel'])
df_test['label'] = df_test['nameLabel'].replace(df_test.nameLabel.unique(), [*range(len(df_test.nameLabel.unique()))])
df_test['label'] = df_test['label'].astype(str)

# Nettoyage variables inutiles
del liste_test

print(df_test["nameLabel"].value_counts())
df_test.head()
# Out:
# Normal             100
# COVID              100
# Lung_Opacity       100
# Viral Pneumonia    100
# Name: nameLabel, dtype: int64
#                                             filepath nameLabel label
# 0  /content/gdrive/MyDrive/Projet Radio_DS/data/N...    Normal     0
# 1  /content/gdrive/MyDrive/Projet Radio_DS/data/N...    Normal     0
# 2  /content/gdrive/MyDrive/Projet Radio_DS/data/N...    Normal     0
# 3  /content/gdrive/MyDrive/Projet Radio_DS/data/N...    Normal     0
# 4  /content/gdrive/MyDrive/Projet Radio_DS/data/N...    Normal     0

# %%
### Exemple d'image

filepath = df.filepath[9]

im = tf.io.read_file(filepath)
im = tf.image.decode_jpeg(im, channels = 1)
plt.imshow(im)
plt.axis('off');

# %% [markdown]
# # Itérateurs d'images

# %%
# Séparation dataframe en ensemble entrainement et validation
train, valid = train_test_split(df, test_size=RATIO_VAL, shuffle = False)


# Création des itérateurs qui chargeront des lots d'images
train_data_generator = ImageDataGenerator( )
valid_data_generator = ImageDataGenerator( )
test_data_generator = ImageDataGenerator( )

# Initialisation du image generator de train
print(f"Number of rows in train set: {len(train)}")
train_generator = train_data_generator.flow_from_dataframe(dataframe = train,
                                                           x_col="filepath",
                                                           y_col="label",
                                                           class_mode = "sparse",
                                                           target_size = SIZE, #Resize
                                                           batch_size = BATCH_SIZE,
                                                           color_mode = "grayscale"
                                                           )

# Initialisation du image generator de validation
print(f"Number of rows in valid set: {len(valid)}")
valid_generator = valid_data_generator.flow_from_dataframe(dataframe = valid,
                                                         x_col="filepath",
                                                         y_col="label",
                                                         class_mode = "sparse",
                                                         target_size = SIZE, #Resize
                                                         batch_size = BATCH_SIZE,
                                                         color_mode = "grayscale",
                                                         shuffle = False)


# Initialisation du image generator de test
print(f"Number of rows in test set: {len(df_test)}")
test_generator = test_data_generator.flow_from_dataframe(dataframe = df_test, #Utilisation du dataframe de test
                                                         x_col="filepath",
                                                         y_col="label",
                                                         class_mode = "sparse",
                                                         target_size = SIZE, #Resize
                                                         batch_size = BATCH_SIZE,
                                                         color_mode = "grayscale", # Pas de grayscale, en rgb
                                                         shuffle = False)
# Out:
# Number of rows in train set: 1280
# Found 1280 validated image filenames belonging to 4 classes.
# Number of rows in valid set: 320
# Found 320 validated image filenames belonging to 4 classes.
# Number of rows in test set: 400
# Found 400 validated image filenames belonging to 4 classes.

# %% [markdown]
# # Création du modèle

# %%
#Chargement et freeze modèle de base Eficient Net
base_model = EfficientNetB1(weights = 'imagenet', include_top=False, input_shape=(240,240,3))
for layer in base_model.layers :
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 [==============================] - 0s 0us/step

# %%
hp = kt.HyperParameters()

# %%
def model_builder(hp) :
    model = Sequential()

    model.add(base_model)

    model.add(GlobalAveragePooling2D())
    model.add(Dense(units = 1024, activation = 'relu'))
    model.add(Dropout(rate = 0.2))
    model.add(Dense(units = 512, activation = 'relu'))
    model.add(Dropout(rate = 0.2))
    model.add(Dense(units = nbClasses, activation = 'softmax'))

    # Optimise le learning rate pour l'optimizer
    hp_learning_rate = hp.Float('lrate_adam', min_value=1e-4, max_value=1e-2, sampling='LOG')

    model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  optimizer = tf.keras.optimizers.Adam(learning_rate = hp_learning_rate),
                  metrics = ["accuracy"])

    return model

# %%
model_builder(kt.HyperParameters()).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb1 (Functional)  (None, 8, 8, 1280)       6575239
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 8,413,835
# Trainable params: 1,838,596
# Non-trainable params: 6,575,239
# _________________________________________________________________

# %% [markdown]
# # Optimisation des hyperparamètres et entrainement du modèle

# %%
tuner = kt.RandomSearch(hypermodel = model_builder, objective = "val_accuracy", max_trials = 3, executions_per_trial = 2,
                        overwrite = True, directory = "kt", project_name = "radio",)

# Callback early stopping
stop_early = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 5)

# Récupération des tailles d'échantillon
train_size = train_generator.samples
valid_size = valid_generator.samples

# Entrainement du modèle avec callback
tuner.search(train_generator,
                    epochs = NB_EPOCHS,
                    steps_per_epoch = train_size // MODEL_BATCH_SIZE,
                    validation_data = valid_generator,
                    validation_steps = valid_size // MODEL_BATCH_SIZE,
                    verbose = 1,
                    callbacks = [stop_early])
# Out:
# Trial 3 Complete [00h 03m 11s]
# val_accuracy: 0.8156249821186066
#
# Best val_accuracy So Far: 0.8343749940395355
# Total elapsed time: 00h 16m 37s

# %%
# Récupération meilleur taux d'apprentissage
best_hps = tuner.get_best_hyperparameters(num_trials = 1)[0]

print(best_hps.get('lrate_adam'))
# Out:
# 0.00016577111356694404

# %%
# Création du modèle avec taux d'apprentissage optimal et entrainement
model_ini = tuner.hypermodel.build(best_hps)

history_ini = model_ini.fit(train_generator,
                    epochs = NB_EPOCHS,
                    steps_per_epoch = train_size // MODEL_BATCH_SIZE,
                    validation_data = valid_generator,
                    validation_steps = valid_size // MODEL_BATCH_SIZE,
                    verbose = 1)
# Out:
# Epoch 1/30
# 40/40 [==============================] - 18s 170ms/step - loss: 0.9390 - accuracy: 0.6102 - val_loss: 0.6382 - val_accuracy: 0.7344
# Epoch 2/30
# 40/40 [==============================] - 5s 135ms/step - loss: 0.6792 - accuracy: 0.7227 - val_loss: 0.5638 - val_accuracy: 0.7594
# Epoch 3/30
# 40/40 [==============================] - 5s 117ms/step - loss: 0.6318 - accuracy: 0.7375 - val_loss: 0.5394 - val_accuracy: 0.7906
# Epoch 4/30
# 40/40 [==============================] - 5s 131ms/step - loss: 0.5659 - accuracy: 0.7547 - val_loss: 0.5295 - val_accuracy: 0.7625
# Epoch 5/30
# 40/40 [==============================] - 5s 127ms/step - loss: 0.5754 - accuracy: 0.7695 - val_loss: 0.5250 - val_accuracy: 0.7719
# Epoch 6/30
# 40/40 [==============================] - 5s 124ms/step - loss: 0.5414 - accuracy: 0.7781 - val_loss: 0.5033 - val_accuracy: 0.7844
# Epoch 7/30
# 40/40 [==============================] - 5s 117ms/step - loss: 0.5020 - accuracy: 0.7961 - val_loss: 0.4791 - val_accuracy: 0.8062
# Epoch 8/30
# 40/40 [==============================] - 5s 128ms/step - loss: 0.5013 - accuracy: 0.7984 - val_loss: 0.5061 - val_accuracy: 0.7781
# Epoch 9/30
# 40/40 [==============================] - 5s 123ms/step - loss: 0.4949 - accuracy: 0.7820 - val_loss: 0.4790 - val_accuracy: 0.7969
# Epoch 10/30
# 40/40 [==============================] - 5s 116ms/step - loss: 0.4652 - accuracy: 0.8133 - val_loss: 0.4535 - val_accuracy: 0.7969
# Epoch 11/30
# 40/40 [==============================] - 5s 131ms/step - loss: 0.4714 - accuracy: 0.8008 - val_loss: 0.4446 - val_accuracy: 0.8438
# Epoch 12/30
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4450 - accuracy: 0.8203 - val_loss: 0.5013 - val_accuracy: 0.8031
# Epoch 13/30
# 40/40 [==============================] - 5s 117ms/step - loss: 0.4381 - accuracy: 0.8180 - val_loss: 0.4696 - val_accuracy: 0.8062
# Epoch 14/30
# 40/40 [==============================] - 5s 135ms/step - loss: 0.4158 - accuracy: 0.8250 - val_loss: 0.4400 - val_accuracy: 0.8219
# Epoch 15/30
# 40/40 [==============================] - 5s 116ms/step - loss: 0.4420 - accuracy: 0.8172 - val_loss: 0.5317 - val_accuracy: 0.7750
# Epoch 16/30
# 40/40 [==============================] - 5s 117ms/step - loss: 0.4188 - accuracy: 0.8297 - val_loss: 0.4857 - val_accuracy: 0.8062
# Epoch 17/30
# 40/40 [==============================] - 5s 130ms/step - loss: 0.3781 - accuracy: 0.8469 - val_loss: 0.4404 - val_accuracy: 0.8156
# Epoch 18/30
# 40/40 [==============================] - 5s 127ms/step - loss: 0.3614 - accuracy: 0.8469 - val_loss: 0.4624 - val_accuracy: 0.8062
# Epoch 19/30
# 40/40 [==============================] - 5s 117ms/step - loss: 0.3979 - accuracy: 0.8367 - val_loss: 0.4660 - val_accuracy: 0.8250
# Epoch 20/30
# 40/40 [==============================] - 5s 133ms/step - loss: 0.3534 - accuracy: 0.8555 - val_loss: 0.4354 - val_accuracy: 0.8250
# Epoch 21/30
# 40/40 [==============================] - 5s 117ms/step - loss: 0.3359 - accuracy: 0.8633 - val_loss: 0.4566 - val_accuracy: 0.8281
# Epoch 22/30
# 40/40 [==============================] - 5s 118ms/step - loss: 0.3676 - accuracy: 0.8461 - val_loss: 0.4354 - val_accuracy: 0.8250
# Epoch 23/30
# 40/40 [==============================] - 5s 132ms/step - loss: 0.3567 - accuracy: 0.8602 - val_loss: 0.4668 - val_accuracy: 0.8094
# Epoch 24/30
# 40/40 [==============================] - 5s 127ms/step - loss: 0.3350 - accuracy: 0.8469 - val_loss: 0.4366 - val_accuracy: 0.8313
# Epoch 25/30
# 40/40 [==============================] - 5s 116ms/step - loss: 0.3272 - accuracy: 0.8625 - val_loss: 0.4860 - val_accuracy: 0.8031
# Epoch 26/30
# 40/40 [==============================] - 5s 129ms/step - loss: 0.3109 - accuracy: 0.8695 - val_loss: 0.4442 - val_accuracy: 0.8188
# Epoch 27/30
# 40/40 [==============================] - 5s 118ms/step - loss: 0.3008 - accuracy: 0.8898 - val_loss: 0.4299 - val_accuracy: 0.8219
# Epoch 28/30
# 40/40 [==============================] - 5s 128ms/step - loss: 0.2905 - accuracy: 0.8891 - val_loss: 0.4907 - val_accuracy: 0.8188
# Epoch 29/30
# 40/40 [==============================] - 5s 117ms/step - loss: 0.3142 - accuracy: 0.8734 - val_loss: 0.4651 - val_accuracy: 0.8156
# Epoch 30/30
# 40/40 [==============================] - 5s 124ms/step - loss: 0.2813 - accuracy: 0.8883 - val_loss: 0.4627 - val_accuracy: 0.8156

# %%
# Récupération meilleure taille nb epochs
val_acc_per_epoch = history_ini.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1

print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 11

# %%
# Réinstanciation de l'hypermodèle et entraînement avec le nombre optimal d'epochs.
model = tuner.hypermodel.build(best_hps)

# Réentrainement du modèle
history = model.fit(train_generator, epochs = best_epoch,
                               steps_per_epoch = train_size // MODEL_BATCH_SIZE,
                               validation_data = valid_generator,
                               validation_steps = valid_size // MODEL_BATCH_SIZE,
                               verbose = 1)
# Out:
# Epoch 1/11
# 40/40 [==============================] - 17s 177ms/step - loss: 0.9331 - accuracy: 0.6094 - val_loss: 0.6867 - val_accuracy: 0.7312
# Epoch 2/11
# 40/40 [==============================] - 5s 130ms/step - loss: 0.6852 - accuracy: 0.7156 - val_loss: 0.5746 - val_accuracy: 0.7656
# Epoch 3/11
# 40/40 [==============================] - 5s 117ms/step - loss: 0.6379 - accuracy: 0.7273 - val_loss: 0.5451 - val_accuracy: 0.7719
# Epoch 4/11
# 40/40 [==============================] - 5s 130ms/step - loss: 0.5860 - accuracy: 0.7578 - val_loss: 0.5151 - val_accuracy: 0.8000
# Epoch 5/11
# 40/40 [==============================] - 5s 127ms/step - loss: 0.5548 - accuracy: 0.7633 - val_loss: 0.5462 - val_accuracy: 0.7563
# Epoch 6/11
# 40/40 [==============================] - 5s 117ms/step - loss: 0.5347 - accuracy: 0.7812 - val_loss: 0.5306 - val_accuracy: 0.7719
# Epoch 7/11
# 40/40 [==============================] - 5s 131ms/step - loss: 0.5204 - accuracy: 0.7922 - val_loss: 0.4580 - val_accuracy: 0.8156
# Epoch 8/11
# 40/40 [==============================] - 5s 119ms/step - loss: 0.4821 - accuracy: 0.8102 - val_loss: 0.5168 - val_accuracy: 0.7844
# Epoch 9/11
# 40/40 [==============================] - 5s 132ms/step - loss: 0.4712 - accuracy: 0.8078 - val_loss: 0.4660 - val_accuracy: 0.8094
# Epoch 10/11
# 40/40 [==============================] - 5s 117ms/step - loss: 0.4794 - accuracy: 0.8016 - val_loss: 0.4633 - val_accuracy: 0.7906
# Epoch 11/11
# 40/40 [==============================] - 5s 126ms/step - loss: 0.4832 - accuracy: 0.8000 - val_loss: 0.6100 - val_accuracy: 0.7500

# %%
# Courbes de perte et d'accuracy - modèle initial
plt.figure(figsize = (16,5))

train_acc = history_ini.history['accuracy']
train_loss = history_ini.history['loss']
val_acc = history_ini.history['val_accuracy']
val_loss = history_ini.history['val_loss']

epochs = range(1, len(train_acc) + 1)

# Courbe de perte
plt.subplot(121)
plt.plot(epochs, train_loss, 'g-o', label = 'Training Loss')
plt.plot(epochs, val_loss, 'y-o',  label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0,2)

# Courbe d'accuracy
plt.subplot(122)
plt.plot(epochs, train_acc, 'g-o', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'y-o',  label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show();

# %%
# Courbes de perte et d'accuracy - modèle final
plt.figure(figsize = (16,5))

train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = range(1, len(train_acc) + 1)

# Courbe de perte
plt.subplot(121)
plt.plot(epochs, train_loss, 'g-o', label = 'Training Loss')
plt.plot(epochs, val_loss, 'y-o',  label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0,2)

# Courbe d'accuracy
plt.subplot(122)
plt.plot(epochs, train_acc, 'g-o', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'y-o',  label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show();

# %% [markdown]
# # Evaluation des performances

# %%
#Acccuracy et perte pour ensemble entrainement, validation et test
print('TRAIN loss & accuracy :', model.evaluate(train_generator))
print('\n')
print('VALID loss & accuracy :', model.evaluate(valid_generator))
print('\n')
print('TEST loss & accuracy :', model.evaluate(test_generator))
# Out:
# 40/40 [==============================] - 4s 94ms/step - loss: 0.4978 - accuracy: 0.8062
# TRAIN loss & accuracy : [0.49784502387046814, 0.8062499761581421]
#
#
# 10/10 [==============================] - 1s 89ms/step - loss: 0.6100 - accuracy: 0.7500
# VALID loss & accuracy : [0.6100271940231323, 0.75]
#
#
# 13/13 [==============================] - 71s 6s/step - loss: 0.6470 - accuracy: 0.7550
# TEST loss & accuracy : [0.6469672322273254, 0.7549999952316284]

# %%
# Calcul des prédictions (test)

y_pred = np.argmax(model.predict(test_generator), axis = 1)
# Out:
# 13/13 [==============================] - 4s 115ms/step

# %%
# Fonction d'affichage de matrice de confusion
def plot_confusion_matrix(cm, classes,
                          normalize = False,
                          title = 'Confusion Matrix',
                          cmap = plt.cm.Blues):

    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.grid(False)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 fontsize = 12,
                 horizontalalignment = "center",
                 color = "white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# Calcul et affichage matrice de confusion
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, classes, normalize = False)

# %%
# Rapport de classification

print(classification_report(test_generator.classes, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.91      0.74       100
#            1       0.66      0.78      0.72       100
#            2       0.98      0.44      0.61       100
#            3       0.97      0.89      0.93       100
#
#     accuracy                           0.76       400
#    macro avg       0.81      0.76      0.75       400
# weighted avg       0.81      0.76      0.75       400

# %% [markdown]
# # Prédictions sur des images test

# %%
# Stockage de l'ensemble de test en array
X_test = []
for filepath in tqdm(df_test['filepath']) :
    im = tf.io.read_file(filepath)
    im = tf.image.decode_jpeg(im, channels = 1)
    im = tf.image.resize (im, SIZE)
    X_test.append([im])

X_test = tf.concat(X_test, axis = 0)
# Out:
# 100%|██████████| 400/400 [00:01<00:00, 298.52it/s]

# %%
# Choix d'images au hasard et affichage

y_test = pd.DataFrame(test_generator.classes).astype(int)

indices_random = tf.random.uniform([5], 0, len(df_test['filepath']), dtype = tf.int32)

plt.figure(figsize = (20,10))

for i, idx in enumerate(indices_random) :
    plt.subplot(1,5,i+1)
    plt.imshow(tf.cast(X_test[idx], tf.int32))
    plt.axis('off')
    plt.title('Pred class : {} \n Real Class : {}'.format(df_test.nameLabel.unique()[y_pred[idx]], df_test.nameLabel.unique()[y_test.values[idx]]))

# %% [markdown]
# # Sauvegarde et chargement modèles

# %%
#Enregistrement modèle
model.save_weights(path + "model_efnet1_kt_2000im_30ep.h5")

# %%
#Chargement modèle
model.load_weights(path + "model_efnet1_kt_2000im_30ep.h5")
